# %%
from project import *
import torch
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('./data/PoetryFoundationData.csv', usecols=['Poem', 'Tags'])
data = data.dropna()

tag_dict = Counter()

for tags in data['Tags']:
    tag_list = tags.replace(" & ", ",").split(',')
    tag_dict.update(tag_list)
    

print(tag_dict)
# Out:
# Counter({'Living': 6243, 'Social Commentaries': 4302, 'Relationships': 3856, 'Nature': 3613, 'Sciences': 3183, 'Arts': 3039, 'Love': 2126, 'Activities': 2107, 'Death': 1547, 'Religion': 1483, 'Time': 1468, 'Brevity': 1468, 'History': 1456, 'Politics': 1456, 'Family': 1345, 'Ancestors': 1345, 'The Body': 1336, 'Life Choices': 1190, 'Poetry': 1077, 'Poets': 1077, 'War': 1053, 'Conflict': 1053, 'Animals': 1036, 'The Mind': 959, 'Philosophy': 912, 'Sorrow': 842, 'Grieving': 842, 'Landscapes': 834, 'Pastorals': 834, 'Travels': 815, 'Journeys': 815, 'Men': 749, 'Women': 749, 'Desire': 735, 'Race': 714, 'Ethnicity': 714, 'Mythology': 690, 'Folklore': 690, 'Realistic': 665, 'Complicated': 665, 'Cities': 648, 'Urban Life': 648, 'Trees': 628, 'Flowers': 628, 'Home Life': 596, 'Gender': 572, 'Sexuality': 572, 'Seas': 568, ' Rivers': 568, '': 568, 'Streams': 568, 'Disappointment': 520, 'Failure': 520, 'Language': 506, 'Linguistics': 506, 'Parenthood': 503, 'Jobs': 490, 'Working': 490, 'Romantic Love': 486, 'Growing Old': 474, 'Christianity': 454, 'God': 446, 'the Divine': 446, 'Friends': 443, 'Enemies': 443, 'Humor': 423, 'Satire': 423, 'Health': 404, 'Illness': 404, 'Reading': 404, 'Books': 404, 'The Spiritual': 385, 'Music': 378, 'Eating': 377, 'Drinking': 377, 'Marriage': 377, 'Companionship': 377, 'Money': 376, 'Economics': 376, 'Coming of Age': 362, 'Faith': 357, 'Doubt': 357, 'Class': 356, 'Heartache': 346, 'Loss': 346, 'Popular Culture': 345, 'Infatuation': 317, 'Crushes': 317, 'Weather': 306, 'Heroes': 301, 'Patriotism': 301, 'Crime': 273, 'Punishment': 273, 'Break-ups': 271, 'Vexed Love': 271, 'Pets': 268, 'Winter': 268, 'Stars': 265, ' Planets': 265, ' Heavens': 265, 'Painting': 259, 'Sculpture': 259, 'School': 245, 'Learning': 245, 'Sports': 239, 'Outdoor Activities': 239, 'Greek': 200, 'Roman Mythology': 200, 'Summer': 185, 'Unrequited Love': 162, 'Youth': 156, 'Separation': 148, 'Divorce': 148, 'Spring': 140, 'Fall': 138, 'Fairy-tales': 127, 'Legends': 127, 'Ghosts': 127, 'the Supernatural': 127, 'Town': 123, 'Country Life': 123, 'Midlife': 123, 'Classic Love': 123, 'Gay': 122, ' Lesbian': 122, ' Queer': 122, 'Photography': 114, 'Film': 114, "Valentine's Day": 108, 'Theater': 100, 'Dance': 100, 'Judaism': 97, 'Indoor Activities': 94, 'Gardening': 92, 'Architecture': 85, 'Design': 85, 'Funerals': 85, 'Horror': 74, 'Infancy': 65, 'Other Religions': 57, 'Anniversary': 57, 'First Love': 51, 'Farewells': 50, 'Good Luck': 50, "Father's Day": 43, 'Birthdays': 39, 'Weddings': 39, 'Christmas': 38, 'Memorial Day': 36, 'Birth': 35, 'Independence Day': 32, 'Islam': 32, 'New Year': 26, 'Engagement': 24, 'Halloween': 23, 'Buddhism': 21, "Mother's Day": 20, 'Graduation': 19, 'Thanksgiving': 18, "St. Patrick's Day": 17, 'Gratitude': 15, 'Apologies': 15, 'Kwanzaa': 14, 'Labor Day': 13, 'Toasts': 13, 'Celebrations': 13, 'Get Well': 12, 'Recovery': 12, 'Easter': 11, 'Yom Kippur': 8, 'Passover': 8, 'September 11th': 8, 'Hanukkah': 5, 'Rosh Hashanah': 5, 'Ramadan': 3, 'Cinco de Mayo': 1})

# %%
tag_df = pd.DataFrame(tag_dict.items(), columns=['Tag', 'Count'])
tag_df = tag_df.sort_values(by='Count', ascending=False)
sns.barplot(x='Tag', y='Count', data=tag_df.head(30))
plt.xticks(rotation=45, ha='right')
plt.xlabel('Tags')
plt.ylabel('Frequency')
plt.show()
