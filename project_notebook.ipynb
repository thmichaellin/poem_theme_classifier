# %% [markdown]
# # Poetry Classification
# **Authors**: Svenja Kratzke, Yitong Li, Michael Lin
# **Date**: 2024-03-12

# %%
from classes import *

# %%
poetry = PoetryData('./data/PoetryFoundationData.csv', ['Poem', 'Tags'])
poetry.load_translate_dict('cluster_tags.json')
poetry.plot_tags(10)

# %%
print(poetry.data)
# Out:
#        index                                               Poem  \
# 0          6  Invisible fish swim this ghost ocean now descr...
# 1          7  Don’t bother the earth spirit who lives here. ...
# 2          9  Hour in which I consider hydrangea, a salt or ...
# 3         16  my father’s body is a map a record of his jour...
# 4         17  it has long been forgotten this practice of th...
# ...      ...                                                ...
# 12894  13835  Dear Writers, I’m compiling the first in what ...
# 12895  13848  The Wise Men will unlearn your name. Above you...
# 12896  13849  We'd like to talk with you about fear they sai...
# 12897  13852  Philosophic in its complex, ovoid emptiness, a...
# 12898  13853  Dear Writers, I’m compiling the first in what ...
#
#                                                     Tags
# 0      {Relationships_and_Family, History_and_Politic...
# 1      {Arts_Culture_and_Beliefs, Life_and_Spirituality}
# 2      {Nature_and_the_Outdoors, Relationships_and_Fa...
# 3      {Relationships_and_Family, Life_and_Spirituality}
# 4      {Relationships_and_Family, Life_and_Spirituality}
# ...                                                  ...
# 12894  {Relationships_and_Family, Arts_Culture_and_Be...
# 12895  {Nature_and_the_Outdoors, Activities_and_Daily...
# 12896  {Social_and_Cultural_Commentary, Life_and_Spir...
# 12897  {Relationships_and_Family, Arts_Culture_and_Be...
# 12898  {Relationships_and_Family, Arts_Culture_and_Be...
#
# [12899 rows x 3 columns]

# %%
print(poetry.exploded_tags)
# Out:
# 0              Relationships_and_Family
# 0                  History_and_Politics
# 0               Nature_and_the_Outdoors
# 0                 Life_and_Spirituality
# 0        Social_and_Cultural_Commentary
#                       ...
# 12897          Arts_Culture_and_Beliefs
# 12898          Relationships_and_Family
# 12898          Arts_Culture_and_Beliefs
# 12898                  Love_and_Romance
# 12898    Social_and_Cultural_Commentary
# Name: Tags, Length: 33186, dtype: object
